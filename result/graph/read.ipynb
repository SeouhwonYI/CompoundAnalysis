# %%
import pandas as pd

# %%
cuisine = "Korean"
recp2mol = pd.read_csv('./'+cuisine+'/000_recipe_molecule_edges.csv')
molweight = pd.read_csv('./'+cuisine+'/001_molecule_weight.csv')
mol2recp = pd.read_csv('./'+cuisine+'/002_molecule_recipe_edges.csv')

# %%
display(recp2mol.head(10))
display(molweight.head(10))
display(mol2recp.head(10))
# Out:
#    recipe_id                             name  rank  molecule  \
# 0          3  Kombu Tea Grilled Chicken Thigh     1      6561
# 1          3  Kombu Tea Grilled Chicken Thigh     2      7284
# 2          3  Kombu Tea Grilled Chicken Thigh     3     11552
# 3          3  Kombu Tea Grilled Chicken Thigh     4       264
# 4          3  Kombu Tea Grilled Chicken Thigh     5      2758
# 5          3  Kombu Tea Grilled Chicken Thigh     6      2879
# 6          3  Kombu Tea Grilled Chicken Thigh     7      3314
# 7          3  Kombu Tea Grilled Chicken Thigh     8      6736
# 8          3  Kombu Tea Grilled Chicken Thigh     9      7460
# 9          3  Kombu Tea Grilled Chicken Thigh    10      7991
#
#            molecule_name                                     flavor_profile  \
# 0       Isobutyraldehyde  {'malt', 'floral', 'fresh', 'pungent', 'aldehy...
# 1  2-Methylbutyraldehyde    {'nutty', 'cocoa', 'almond', 'musty', 'coffee'}
# ...
